# %% [markdown]
# **Reference for Template design: Anthony So**

# %% [markdown]
# ---
# ---
# ***B. PART B: EXPERIMENT ON MULTIVARIATE LINEAR REGRESSION***
# ---
# ---

# %% [markdown]
# **I. Load and Explore Dataset**

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path1='/content/drive/MyDrive/Colab Notebooks/Data/ML/Assignment 1/cancer_us_county-testing.csv'
# path2='/content/drive/MyDrive/Colab Notebooks/Data/ML/Assignment 1/cancer_us_county-training.csv'
# import pandas as pd
# df_test=pd.read_csv(path1)
# df_train=pd.read_csv(path2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
path1='cancer_us_county-testing.csv'
path2='cancer_us_county-training.csv'

# %%
df_test=pd.read_csv(path1)
df_train=pd.read_csv(path2)

# %%
df_train
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0       88.000000                40             261.0     561.400000
# 1       73.000000                35             167.3     345.600000
# 2      292.000000               124             191.0     468.400000
# 3     1962.667684                 7             165.4     453.549422
# 4       43.000000                20             160.6     349.700000
# ...           ...               ...               ...            ...
# 2433   389.000000               157             185.3     456.600000
# 2434   286.000000               117             196.7     492.400000
# 2435   103.000000                42             204.1     506.700000
# 2436  1962.667684                23             171.1     453.549422
# 2437   219.000000                89             179.7     449.100000
#
#       medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %%
'Display the dimensions (shape) of df train'
df_train.shape
# Out:
# (2438, 35)

# %%
df_test
# Out:
#      avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0     449.000000               154             159.5     479.800000
# 1     340.000000               140             167.2     438.500000
# 2      54.000000                18             131.6     410.800000
# 3      94.000000                46             189.4     403.800000
# 4    2718.000000              1065             168.9     432.100000
# ..           ...               ...               ...            ...
# 604    27.000000                14             187.6     415.700000
# 605    30.000000                 9             131.6     444.600000
# 606   583.000000               258             187.5     429.400000
# 607  1962.667684                31             174.2     453.549422
# 608    42.000000                17             199.1     491.800000
#
#      medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %%
'Display the dimensions (shape) of df test'
df_test.shape
# Out:
# (609, 35)

# %% [markdown]
# **II. DATA PREPARATION:**

# %% [markdown]
# **1. Descriptive statistics**

# %%
df_train.describe()
# Out:
#         avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# count   2438.000000       2438.000000       2438.000000    2438.000000
# mean     587.171930        180.592699        178.848482     448.308247
# std     1236.447895        438.473144         27.538452      53.247868
# min        6.000000          3.000000         66.300000     201.300000
# 25%       76.000000         28.000000        161.400000     420.300000
# 50%      172.500000         62.000000        178.100000     453.549422
# 75%      521.500000        151.000000        195.300000     481.975000
# max    24965.000000       9445.000000        293.900000    1014.200000
#
#            medIncome    popEst2015  povertyPercent  studyPerCap    MedianAge  \
# count    2438.000000  2.438000e+03     2438.000000  2438.000000  2438.000000
# mean    47028.427810  9.851579e+04       16.854348   166.019192    45.313782
# std     11919.386622  2.745272e+05        6.388398   563.813830    45.053173
# ...

# %%
df_train.isna().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# TARGET_deathRate              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            1826
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          122
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     500
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# ...

# %%
df_test.isna().sum()
# Out:
# avgAnnCount                  0
# avgDeathsPerYear             0
# TARGET_deathRate             0
# incidenceRate                0
# medIncome                    0
# popEst2015                   0
# povertyPercent               0
# studyPerCap                  0
# binnedInc                    0
# MedianAge                    0
# MedianAgeMale                0
# MedianAgeFemale              0
# Geography                    0
# AvgHouseholdSize             0
# PercentMarried               0
# PctNoHS18_24                 0
# PctHS18_24                   0
# PctSomeCol18_24            459
# PctBachDeg18_24              0
# PctHS25_Over                 0
# PctBachDeg25_Over            0
# PctEmployed16_Over          30
# PctUnemployed16_Over         0
# PctPrivateCoverage           0
# PctPrivateCoverageAlone    109
# PctEmpPrivCoverage           0
# PctPublicCoverage            0
# PctPublicCoverageAlone       0
# PctWhite                     0
# PctBlack                     0
# ...

# %% [markdown]
# **2. Display the observations with missing values**

# %%
df_train[df_train['PctSomeCol18_24'].isnull()]
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0       88.000000                40             261.0     561.400000
# 1       73.000000                35             167.3     345.600000
# 2      292.000000               124             191.0     468.400000
# 4       43.000000                20             160.6     349.700000
# 6     1962.667684                36             153.9     453.549422
# ...           ...               ...               ...            ...
# 2432   124.000000                56             208.3     469.100000
# 2433   389.000000               157             185.3     456.600000
# 2434   286.000000               117             196.7     492.400000
# 2435   103.000000                42             204.1     506.700000
# 2436  1962.667684                23             171.1     453.549422
#
#       medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %%
df_train[df_train['PctEmployed16_Over'].isnull()]
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 17    1780.000000               748             169.1     418.700000
# 73     407.000000               126             174.0     536.200000
# 88    1962.667684                 6             141.4     453.549422
# 98      33.000000                11             138.7     380.500000
# 107     55.000000                25             198.5     457.800000
# ...           ...               ...               ...            ...
# 2256    13.000000                 6             197.5     444.000000
# 2338  1962.667684               571             154.4     453.549422
# 2358   168.000000                75             233.1     516.900000
# 2368   549.000000               210             185.2     493.900000
# 2427   228.000000                81             179.3     537.300000
#
#       medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %%
df_train[df_train['PctPrivateCoverageAlone'].isnull()]
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 9           404.0               134             150.9          480.7
# 12           10.0                 5             151.4          300.1
# 16          511.0               163             156.2          473.8
# 23           26.0                10             106.5          357.4
# 32         1003.0               395             191.5          501.1
# ...           ...               ...               ...            ...
# 2402         43.0                19             229.5          548.3
# 2410        117.0                42             143.7          416.2
# 2412         96.0                38             174.0          460.0
# 2418        249.0                88             224.4          651.3
# 2424         14.0                 5             166.8          448.3
#
#       medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %%
df_test[df_test['PctSomeCol18_24'].isnull()]
# Out:
#      avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0          449.0               154             159.5          479.8
# 1          340.0               140             167.2          438.5
# 3           94.0                46             189.4          403.8
# 4         2718.0              1065             168.9          432.1
# 5            9.0                 3             130.6          349.8
# ..           ...               ...               ...            ...
# 603        286.0               122             161.1          393.0
# 604         27.0                14             187.6          415.7
# 605         30.0                 9             131.6          444.6
# 606        583.0               258             187.5          429.4
# 608         42.0                17             199.1          491.8
#
#      medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %%
df_test[df_test['PctEmployed16_Over'].isnull()]
# Out:
#      avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 3      94.000000                46             189.4     403.800000
# 7      38.000000                17             153.9     388.800000
# 20     25.000000                10             165.6     473.100000
# 34     50.000000                21             181.9     463.500000
# 35   1962.667684               138             153.7     453.549422
# 43   1962.667684                11             176.2     453.549422
# 54    181.000000                81             183.9     427.400000
# 65    627.000000               242             165.1     430.400000
# 114   677.000000               297             195.5     443.600000
# 139   110.000000                52             214.9     471.500000
# 143    60.000000                25             186.1     473.600000
# 183   126.000000                59             147.4     316.500000
# 213  1186.000000               346             131.9     418.100000
# ...

# %%
df_test[df_test['PctPrivateCoverageAlone'].isnull()]
# Out:
#      avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 10    257.000000               114             248.2     550.300000
# 11    120.000000                49             155.8     385.400000
# 24     86.000000                36             166.0     423.200000
# 27    346.000000               156             176.8     399.000000
# 31    131.000000                46             179.7     511.700000
# ..           ...               ...               ...            ...
# 585  1962.667684                 9             150.7     453.549422
# 586    17.000000                 7             116.0     307.300000
# 589   175.000000                78             180.1     405.300000
# 592    99.000000                41             183.7     457.400000
# 603   286.000000               122             161.1     393.000000
#
#      medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# ...

# %% [markdown]
# **3. Replace all missing values with its mean**

# %%
df_train.isnull().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# TARGET_deathRate              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            1826
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          122
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     500
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# ...

# %%
df_train['PctSomeCol18_24'] = df_train['PctSomeCol18_24'].fillna(df_train['PctSomeCol18_24'].mean())

# %%
df_train['PctEmployed16_Over'] = df_train['PctEmployed16_Over'].fillna(df_train['PctEmployed16_Over'].mean())

# %%
df_train['PctPrivateCoverageAlone'] = df_train['PctPrivateCoverageAlone'].fillna(df_train['PctPrivateCoverageAlone'].mean())

# %%
df_train.isnull().sum()
# Out:
# avgAnnCount                0
# avgDeathsPerYear           0
# TARGET_deathRate           0
# incidenceRate              0
# medIncome                  0
# popEst2015                 0
# povertyPercent             0
# studyPerCap                0
# binnedInc                  0
# MedianAge                  0
# MedianAgeMale              0
# MedianAgeFemale            0
# Geography                  0
# AvgHouseholdSize           0
# PercentMarried             0
# PctNoHS18_24               0
# PctHS18_24                 0
# PctSomeCol18_24            0
# PctBachDeg18_24            0
# PctHS25_Over               0
# PctBachDeg25_Over          0
# PctEmployed16_Over         0
# PctUnemployed16_Over       0
# PctPrivateCoverage         0
# PctPrivateCoverageAlone    0
# PctEmpPrivCoverage         0
# PctPublicCoverage          0
# PctPublicCoverageAlone     0
# PctWhite                   0
# PctBlack                   0
# PctAsian                   0
# PctOtherRace               0
# ...

# %%
df_test['PctSomeCol18_24'] = df_test['PctSomeCol18_24'].fillna(df_test['PctSomeCol18_24'].mean())

# %%
df_test['PctEmployed16_Over'] = df_test['PctEmployed16_Over'].fillna(df_test['PctEmployed16_Over'].mean())

# %%
df_test['PctPrivateCoverageAlone'] = df_test['PctPrivateCoverageAlone'].fillna(df_test['PctPrivateCoverageAlone'].mean())

# %%
df_test.isnull().sum()
# Out:
# avgAnnCount                0
# avgDeathsPerYear           0
# TARGET_deathRate           0
# incidenceRate              0
# medIncome                  0
# popEst2015                 0
# povertyPercent             0
# studyPerCap                0
# binnedInc                  0
# MedianAge                  0
# MedianAgeMale              0
# MedianAgeFemale            0
# Geography                  0
# AvgHouseholdSize           0
# PercentMarried             0
# PctNoHS18_24               0
# PctHS18_24                 0
# PctSomeCol18_24            0
# PctBachDeg18_24            0
# PctHS25_Over               0
# PctBachDeg25_Over          0
# PctEmployed16_Over         0
# PctUnemployed16_Over       0
# PctPrivateCoverage         0
# PctPrivateCoverageAlone    0
# PctEmpPrivCoverage         0
# PctPublicCoverage          0
# PctPublicCoverageAlone     0
# PctWhite                   0
# PctBlack                   0
# PctAsian                   0
# PctOtherRace               0
# ...

# %% [markdown]
# **III. VARIABLES**

# %%
testing3=df_test.copy()
training3=df_train.copy()

# %%
X_train3=training3[['PctNoHS18_24','PctHS18_24','PctSomeCol18_24','PctBachDeg18_24','PctHS25_Over','PctBachDeg25_Over','PctEmployed16_Over','PctUnemployed16_Over']]

# %%
X_test3=testing3[['PctNoHS18_24','PctHS18_24','PctSomeCol18_24','PctBachDeg18_24','PctHS25_Over','PctBachDeg25_Over','PctEmployed16_Over','PctUnemployed16_Over']]

# %%
y_test3=testing3['TARGET_deathRate'].values

# %%
y_train3=training3['TARGET_deathRate'].values

# %% [markdown]
# **IV. ACCESS BASELINE MODEL**

# %% [markdown]
# 1.Find the average of the target variable

# %%
y_mean = y_train3.mean()

# %% [markdown]
# 2.Create a numpy array called y_base filled with this value

# %%
import numpy as np

# %%
y_base = np.full(y_train3.shape, y_mean)

# %%
y_base
# Out:
# array([178.84848236, 178.84848236, 178.84848236, ..., 178.84848236,
#        178.84848236, 178.84848236])

# %% [markdown]
# 3.Import the MSE and MAE from sklearn

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %% [markdown]
# 4.Display the MSE and MAE scores of this baseline model

# %%
print(mse(y_train3, y_base, squared=True))
print(mae(y_train3, y_base))
# Out:
# 758.055254054447
# 21.31608117575091

# %% [markdown]
# **IV. TRAINING MULTIVARIATE LINEAR REGRESSION (ALL VARIABLES)**

# %% [markdown]
# 1.Import train_test_split from sklearn.model_selection

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 2.Instantiate the LinearRegression class into a variable called reg3

# %%
from sklearn.linear_model import LinearRegression

# %%
reg3 = LinearRegression()

# %% [markdown]
# 3.Fit the model with the all features:

# %%
reg3.fit(X_train3, y_train3)
# Out:
# LinearRegression()

# %% [markdown]
# 4.Use the trained model to predict the outcome on X_train3 and save them into y_preds3

# %%
y_train_preds3 = reg3.predict(X_train3)

# %% [markdown]
# 5.Calculate the RMSE and MAE on the training datasets

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %%
print(mse(y_train3, y_train_preds3, squared=True))
print(mae(y_train3, y_train_preds3))
# Out:
# 500.6754669358324
# 16.871121083077497

# %% [markdown]
# 5. Import the altair package

# %%
import altair as alt

# %% [markdown]
# 6. Display the predictions versus the target line charts on the training set

# %%
y_train3
# Out:
# array([261. , 167.3, 191. , ..., 204.1, 171.1, 179.7])

# %%
y_train_preds3=pd.DataFrame(y_train_preds3)

# %%
y_train_preds3=y_train_preds3.rename(columns={0:"TARGET_deathRate_pred"})

# %%
y_train_preds3
# Out:
#       TARGET_deathRate_pred
# 0                207.058123
# 1                199.113798
# 2                193.594046
# 3                177.430061
# 4                198.343650
# ...                     ...
# 2433             162.734088
# 2434             187.372945
# 2435             199.670900
# 2436             180.953032
# 2437             190.271111
#
# [2438 rows x 1 columns]

# %%
y_train3=pd.DataFrame(y_train3)

# %%
y_train3=y_train3.rename(columns={0:'preds'})

# %%
y_train3
# Out:
#       preds
# 0     261.0
# 1     167.3
# 2     191.0
# 3     165.4
# 4     160.6
# ...     ...
# 2433  185.3
# 2434  196.7
# 2435  204.1
# 2436  171.1
# 2437  179.7
#
# [2438 rows x 1 columns]

# %%
perfect_test = alt.Chart(pd.DataFrame({'target': y_train3['preds'], 'preds': y_train3['preds']})).mark_line(color='green').encode(
    x='target',
    y='preds'
).properties(
    width=800,  # Specify the width of the chart
    height=400  # Specify the height of the chart
)

# %%
pred_chart_test = alt.Chart(pd.DataFrame({'target': y_train3['preds'], 'preds': y_train_preds3['TARGET_deathRate_pred']})).mark_point(color='red').encode(
    x='target',
    y='preds'
).properties(
    width=800,  # Specify the width of the chart
    height=400  # Specify the height of the chart
)

# %%
perfect_test+pred_chart_test
# Out:
# alt.LayerChart(...)

# %% [markdown]
# 7. Display the predictions versus the target line charts on the testing set

# %%
y_test3=pd.DataFrame(y_test3)

# %%
# y_test3=y_test3.rename(columns={0:"TARGET_deathRate_test"})

# %%
y_test_preds3 = reg3.predict(X_test3)
print(mse(y_test3, y_test_preds3, squared=True))
print(mae(y_test3, y_test_preds3))
# Out:
# 641.2139607317395
# 18.208896852367175

# %%
y_test3=y_test3.rename(columns={0:'TARGET_deathRate_test'})

# %%
perfect_test3 = alt.Chart(pd.DataFrame({'target':  y_test3['TARGET_deathRate_test'], 'preds':  y_test3['TARGET_deathRate_test']})).mark_line(color='green').encode(
    x='target',
    y='preds'
).properties(
    width=800,  # Specify the width of the chart
    height=400  # Specify the height of the chart
)

pred_chart_test3 = alt.Chart(pd.DataFrame({'target':  y_test3['TARGET_deathRate_test'], 'preds': y_test_preds3})).mark_line().encode(
    x='target',
    y='preds'
  ).properties(
    width=800,  # Specify the width of the chart
    height=400  # Specify the height of the chart
)

pred_chart_test3 + perfect_test3
# Out:
# alt.LayerChart(...)

# %%
coef=reg3.coef_
intercept=reg3.intercept_

# %%
coef=coef.tolist()

# %%
# coef=coef[0]

# %%
factors=list(X_train3.columns.values)

# %%
print("Intercept: "+str(intercept))
for i in range(len(factors)):
  print(str(factors[i])+": "+ "coef: " +str(coef[i]))
# Out:
# Intercept: 169.0139998740134
# PctNoHS18_24: coef: -0.48340299736422954
# PctHS18_24: coef: 0.15103729852566827
# PctSomeCol18_24: coef: -0.016590731076467746
# PctBachDeg18_24: coef: 0.10058800469406637
# PctHS25_Over: coef: 0.6447768061927206
# PctBachDeg25_Over: coef: -1.4979630716548888
# PctEmployed16_Over: coef: -0.1339327352649171
# PctUnemployed16_Over: coef: 2.2793200835235057
